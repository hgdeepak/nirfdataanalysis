# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Constants

# %%
PROCESSED_FILE_DIRECTORY = r"..\data\excel"

REPORT_FILE_DIRECTORY = r"..\data\report"

# %% [markdown]
# # Get Files

# %%
files = os.listdir(PROCESSED_FILE_DIRECTORY)

files = [f for f in files if os.path.isfile(PROCESSED_FILE_DIRECTORY + '/' + f)]

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Sheet 0

# %%
def get_empty_dataframe(file):
    data_df = pd.DataFrame({'2022-23': [0],
                                '2021-22': [0],
                                '2020-21': [0],
                                '2019-20': [0],
                                '2018-19': [0],
                                '2017-18': [0],
                                'Institution': file.split('.')[0]
                                })
    return data_df

# %%
def process_sheet0():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "0" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:            
                #print(f"Processing the sheet 0 of the file: {file}")

                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="0")
                
                data_df = data_df.iloc[:, 1:]
                data_df.replace('-', 0, inplace=True)  
                
                data_df['2022-23'] = data_df['2022-23'].astype(np.int64)
                data_df['2021-22'] = data_df['2021-22'].astype(np.int64)
                data_df['2020-21'] = data_df['2020-21'].astype(np.int64)                                                             
                data_df['2019-20'] = data_df['2019-20'].astype(np.int64)
                data_df['2018-19'] = data_df['2018-19'].astype(np.int64)
                data_df['2017-18'] = data_df['2017-18'].astype(np.int64)

                data_df['Total'] = data_df['2022-23'] + data_df['2021-22'] + data_df['2020-21'] + data_df['2019-20'] + \
                data_df['2018-19'] + data_df['2017-18']   
            else:
                data_df = get_empty_dataframe(file)
            
            data_df.fillna(0, inplace=True)
            nirf_df = pd.concat([nirf_df, data_df])           
    except Exception as ex:
        print(f"Error while processing the sheet 0 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)
    finally:
        nirf_df = nirf_df.groupby('Institution').sum('Total')[['Total']]
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Total sanctioned approved intake for all programs'}, inplace=True)    

    return nirf_df

# %%
process_sheet0()
# Out:
# Institution                                        1 IR-O-U-0456  \
# Total sanctioned approved intake for all programs           7038
#
# Institution                                        10 IR-O-U-0109  \
# Total sanctioned approved intake for all programs            5118
#
# Institution                                        100 IR-O-U-0470  \
# Total sanctioned approved intake for all programs             2700
#
# Institution                                        11 IR-O-U-0500  \
# Total sanctioned approved intake for all programs           29439
#
# Institution                                        12 IR-O-U-0013  \
# Total sanctioned approved intake for all programs            3008
#
# Institution                                        13 IR-O-U-0108  \
# Total sanctioned approved intake for all programs            8646
#
# Institution                                        14 IR-O-U-0234  \
# Total sanctioned approved intake for all programs           26488
#
# Institution                                        15 IR-O-U-0120  \
# Total sanctioned approved intake for all programs           23676
#
# Institution                                        16 IR-O-U-0496  \
# Total sanctioned approved intake for all programs           19380
#
# Institution                                        17 IR-O-U-0575  ...  \
# Total sanctioned approved intake for all programs           11548  ...
#
# Institution                                        88 IR-O-U-0523  \
# Total sanctioned approved intake for all programs            2859
#
# Institution                                        89 IR-O-U-0190  \
# Total sanctioned approved intake for all programs            4121
#
# Institution                                        9 IR-O-U-0053  \
# Total sanctioned approved intake for all programs           5635
#
# Institution                                        91 IR-O-U-0446  \
# Total sanctioned approved intake for all programs           20629
#
# Institution                                        92 IR-O-U-0055  \
# Total sanctioned approved intake for all programs            4306
#
# Institution                                        93 IR-O-U-0577  \
# Total sanctioned approved intake for all programs            4604
#
# Institution                                        94 IR-O-U-0136  \
# Total sanctioned approved intake for all programs            3540
#
# Institution                                        95 IR-O-U-0642  \
# Total sanctioned approved intake for all programs            2595
#
# Institution                                        97 IR-O-U-0003  \
# Total sanctioned approved intake for all programs            5240
#
# Institution                                        99 IR-O-U-0686
# Total sanctioned approved intake for all programs            1273
#
# [1 rows x 83 columns]

# %% [markdown]
# ### Sheet 1

# %%
def get_empty_dataframe(file):
        data_df = pd.DataFrame({'Total Students': [0], 'Institution': file.split('.')[0]})
        
        return data_df

# %%
def process_sheet1():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 1 of the file: {file}")
                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="1")

                data_df = data_df[['Total Students', 'Institution']]
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])                        
    except Exception as ex:
        print(f"Error while processing the sheet 1 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:                
        nirf_df = nirf_df.groupby('Institution').sum('Total Students')
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total Students': 'Total number of students enrolled in all programs'}, inplace=True)        
    
    return nirf_df

# %%
process_sheet1()
# Out:
# Institution                                        1 IR-O-U-0456  \
# Total number of students enrolled in all programs           7397
#
# Institution                                        10 IR-O-U-0109  \
# Total number of students enrolled in all programs            5199
#
# Institution                                        100 IR-O-U-0470  \
# Total number of students enrolled in all programs             2245
#
# Institution                                        11 IR-O-U-0500  \
# Total number of students enrolled in all programs           29466
#
# Institution                                        12 IR-O-U-0013  \
# Total number of students enrolled in all programs            2788
#
# Institution                                        13 IR-O-U-0108  \
# Total number of students enrolled in all programs            8730
#
# Institution                                        14 IR-O-U-0234  \
# Total number of students enrolled in all programs           24376
#
# Institution                                        15 IR-O-U-0120  \
# Total number of students enrolled in all programs           22894
#
# Institution                                        16 IR-O-U-0496  \
# Total number of students enrolled in all programs           18782
#
# Institution                                        17 IR-O-U-0575  ...  \
# Total number of students enrolled in all programs           10394  ...
#
# Institution                                        88 IR-O-U-0523  \
# Total number of students enrolled in all programs            2574
#
# Institution                                        89 IR-O-U-0190  \
# Total number of students enrolled in all programs            3851
#
# Institution                                        9 IR-O-U-0053  \
# Total number of students enrolled in all programs           5678
#
# Institution                                        91 IR-O-U-0446  \
# Total number of students enrolled in all programs           19448
#
# Institution                                        92 IR-O-U-0055  \
# Total number of students enrolled in all programs            4040
#
# Institution                                        93 IR-O-U-0577  \
# Total number of students enrolled in all programs            4165
#
# Institution                                        94 IR-O-U-0136  \
# Total number of students enrolled in all programs            3537
#
# Institution                                        95 IR-O-U-0642  \
# Total number of students enrolled in all programs            2745
#
# Institution                                        97 IR-O-U-0003  \
# Total number of students enrolled in all programs            5227
#
# Institution                                        99 IR-O-U-0686
# Total number of students enrolled in all programs            1192
#
# [1 rows x 83 columns]

# %%
def process_sheet1_1():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 1 of the file: {file}")
                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="1")

                #data_df = data_df.iloc[:, [7, 8, 13]]
                
                data_df['Total Students'] = data_df.iloc[:, 7] + data_df.iloc[:, 8]
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])                        
    except Exception as ex:
        print(f"Error while processing the sheet 1 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:                
        nirf_df = nirf_df.groupby('Institution').sum('Total Students')
        nirf_df = nirf_df.transpose()
        nirf_df = nirf_df.iloc[[-1], :]
        nirf_df.rename(index={'Total Students': 'Total number of economically socially challenged \
        students enrolled in all programs'}, inplace=True)        
    
    return nirf_df

# %%
process_sheet1_1()
# Out:
# Institution                                         1 IR-O-U-0456  \
# No. of students\rwho are not\rreceiving full\rt...            0.0
#
# Institution                                         10 IR-O-U-0109  \
# No. of students\rwho are not\rreceiving full\rt...          3463.0
#
# Institution                                         100 IR-O-U-0470  \
# No. of students\rwho are not\rreceiving full\rt...            154.0
#
# Institution                                         11 IR-O-U-0500  \
# No. of students\rwho are not\rreceiving full\rt...         10523.0
#
# Institution                                         12 IR-O-U-0013  \
# No. of students\rwho are not\rreceiving full\rt...           695.0
#
# Institution                                         13 IR-O-U-0108  \
# No. of students\rwho are not\rreceiving full\rt...            29.0
#
# Institution                                         14 IR-O-U-0234  \
# No. of students\rwho are not\rreceiving full\rt...          1478.0
#
# Institution                                         15 IR-O-U-0120  \
# No. of students\rwho are not\rreceiving full\rt...         10450.0
#
# Institution                                         16 IR-O-U-0496  \
# No. of students\rwho are not\rreceiving full\rt...          4171.0
#
# Institution                                         17 IR-O-U-0575  ...  \
# No. of students\rwho are not\rreceiving full\rt...           166.0  ...
#
# Institution                                         88 IR-O-U-0523  \
# No. of students\rwho are not\rreceiving full\rt...           120.0
#
# Institution                                         89 IR-O-U-0190  \
# No. of students\rwho are not\rreceiving full\rt...           880.0
#
# Institution                                         9 IR-O-U-0053  \
# No. of students\rwho are not\rreceiving full\rt...         1464.0
#
# Institution                                         91 IR-O-U-0446  \
# No. of students\rwho are not\rreceiving full\rt...          5897.0
#
# Institution                                         92 IR-O-U-0055  \
# No. of students\rwho are not\rreceiving full\rt...           512.0
#
# Institution                                         93 IR-O-U-0577  \
# No. of students\rwho are not\rreceiving full\rt...            21.0
#
# Institution                                         94 IR-O-U-0136  \
# No. of students\rwho are not\rreceiving full\rt...             0.0
#
# Institution                                         95 IR-O-U-0642  \
# No. of students\rwho are not\rreceiving full\rt...            59.0
#
# Institution                                         97 IR-O-U-0003  \
# No. of students\rwho are not\rreceiving full\rt...           157.0
#
# Institution                                         99 IR-O-U-0686
# No. of students\rwho are not\rreceiving full\rt...           413.0
#
# [1 rows x 83 columns]

# %%
def process_sheet1_2():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 1 of the file: {file}")
                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="1")

                data_df = data_df.iloc[:, [9, 10, 11, 13]]
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])                        
    except Exception as ex:
        print(f"Error while processing the sheet 1 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:                
        nirf_df = nirf_df.groupby('Institution').sum()
        nirf_df = nirf_df.transpose()
        #nirf_df.rename(index={'Total Students': 'Total number of economically socially challenged \
        #students enrolled in all programs'}, inplace=True)        
    
    return nirf_df

# %%
process_sheet1_2()
# Out:
# Institution                                         1 IR-O-U-0456  \
# No. of students_x000D_receiving full_x000D_tuit...          308.0
# No. of students_x000D_receiving full_x000D_tuit...         4066.0
# No. of students_x000D_receiving full_x000D_tuit...          527.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
#
# Institution                                         10 IR-O-U-0109  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           262.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
#
# Institution                                         100 IR-O-U-0470  \
# No. of students_x000D_receiving full_x000D_tuit...              0.0
# No. of students_x000D_receiving full_x000D_tuit...              0.0
# No. of students_x000D_receiving full_x000D_tuit...              0.0
# No. of students\rreceiving full\rtuition fee\rr...           1773.0
# No. of students\rreceiving full\rtuition fee\rr...            183.0
# No. of students\rreceiving full\rtuition fee\rr...             90.0
#
# Institution                                         11 IR-O-U-0500  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          7395.0
# No. of students\rreceiving full\rtuition fee\rr...            15.0
# No. of students\rreceiving full\rtuition fee\rr...           153.0
#
# Institution                                         12 IR-O-U-0013  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           129.0
# No. of students\rreceiving full\rtuition fee\rr...           676.0
# No. of students\rreceiving full\rtuition fee\rr...             2.0
#
# Institution                                         13 IR-O-U-0108  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          5207.0
# No. of students\rreceiving full\rtuition fee\rr...          1901.0
# No. of students\rreceiving full\rtuition fee\rr...          1005.0
#
# Institution                                         14 IR-O-U-0234  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           123.0
# No. of students\rreceiving full\rtuition fee\rr...          1450.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
#
# Institution                                         15 IR-O-U-0120  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           331.0
# No. of students\rreceiving full\rtuition fee\rr...          1382.0
# No. of students\rreceiving full\rtuition fee\rr...             1.0
#
# Institution                                         16 IR-O-U-0496  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          3873.0
# No. of students\rreceiving full\rtuition fee\rr...           855.0
# No. of students\rreceiving full\rtuition fee\rr...          2862.0
#
# Institution                                         17 IR-O-U-0575  ...  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0  ...
# No. of students_x000D_receiving full_x000D_tuit...             0.0  ...
# No. of students_x000D_receiving full_x000D_tuit...             0.0  ...
# No. of students\rreceiving full\rtuition fee\rr...          5436.0  ...
# No. of students\rreceiving full\rtuition fee\rr...          1453.0  ...
# No. of students\rreceiving full\rtuition fee\rr...           335.0  ...
#
# Institution                                         88 IR-O-U-0523  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          1402.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
#
# Institution                                         89 IR-O-U-0190  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...            69.0
# No. of students\rreceiving full\rtuition fee\rr...            60.0
# No. of students\rreceiving full\rtuition fee\rr...            12.0
#
# Institution                                         9 IR-O-U-0053  \
# No. of students_x000D_receiving full_x000D_tuit...            0.0
# No. of students_x000D_receiving full_x000D_tuit...            0.0
# No. of students_x000D_receiving full_x000D_tuit...            0.0
# No. of students\rreceiving full\rtuition fee\rr...         1756.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
#
# Institution                                         91 IR-O-U-0446  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           580.0
# No. of students\rreceiving full\rtuition fee\rr...          1635.0
# No. of students\rreceiving full\rtuition fee\rr...           758.0
#
# Institution                                         92 IR-O-U-0055  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           457.0
# No. of students\rreceiving full\rtuition fee\rr...          1489.0
# No. of students\rreceiving full\rtuition fee\rr...            14.0
#
# Institution                                         93 IR-O-U-0577  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           323.0
# No. of students\rreceiving full\rtuition fee\rr...          2355.0
# No. of students\rreceiving full\rtuition fee\rr...            12.0
#
# Institution                                         94 IR-O-U-0136  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          2144.0
# No. of students\rreceiving full\rtuition fee\rr...            16.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
#
# Institution                                         95 IR-O-U-0642  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           289.0
# No. of students\rreceiving full\rtuition fee\rr...            42.0
#
# Institution                                         97 IR-O-U-0003  \
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          5070.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
#
# Institution                                         99 IR-O-U-0686
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           130.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...            90.0
#
# [6 rows x 83 columns]

# %% [markdown]
# ## Sheet 2

# %%
def get_empty_dataframe(file):
    data_df = pd.DataFrame({'Median salary': [0], 'Institution': file.split('.')[0]})
    
    return data_df

# %%
def process_sheet2():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "2" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 2 of the file: {file}")
                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="2")
                    
                    columns = data_df.columns.to_list()
                    median_index = 0
                    institute_index = 0
                    
                    for index, element in enumerate(columns):
                        if element.split()[0] == 'Median':
                            median_index = index                            
                        elif element.split()[0] == 'Institution':
                            institute_index = index

                    data_df = pd.DataFrame({
                        'Median salary': data_df.iloc[:, median_index].values,
                        'Institution': data_df.iloc[:, institute_index].values
                    })

                    data_df['Median salary'] = data_df['Median salary'].str.split(r"(").str[0].astype(np.float64)
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                data_df = get_empty_dataframe(file)
            finally:  
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])           
    except Exception as ex:
        print(f"Error while processing the sheet 2 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)
    finally:            
        nirf_df = nirf_df.groupby('Institution').mean('Median salary')
        nirf_df = nirf_df.transpose()           
    
    return nirf_df

# %%
process_sheet2()
# Out:
# Institution    1 IR-O-U-0456  10 IR-O-U-0109  100 IR-O-U-0470  11 IR-O-U-0500  \
# Median salary   1.621147e+06   666666.666667    246934.666667        750000.0
#
# Institution    12 IR-O-U-0013  13 IR-O-U-0108  14 IR-O-U-0234  15 IR-O-U-0120  \
# Median salary    1.908333e+06        510000.0   333333.333333        500000.0
#
# Institution    16 IR-O-U-0496  17 IR-O-U-0575  ...  88 IR-O-U-0523  \
# Median salary        490262.0   578333.333333  ...   966666.666667
#
# Institution    89 IR-O-U-0190  9 IR-O-U-0053  91 IR-O-U-0446  92 IR-O-U-0055  \
# Median salary   249666.666667   2.093333e+06   398333.333333    1.081667e+06
#
# Institution    93 IR-O-U-0577  94 IR-O-U-0136  95 IR-O-U-0642  97 IR-O-U-0003  \
# Median salary   953333.333333    53058.823529   870333.333333   766666.666667
#
# Institution    99 IR-O-U-0686
# Median salary        820000.0
#
# [1 rows x 83 columns]

# %% [markdown]
# ## Sheet 4

# %%
def get_empty_dataframe(file):
    data_df = pd.DataFrame({'Total': [0], 'Institution': file.split('.')[0]})
    
    return data_df

# %%
def process_sheet4():
    nirf_df = pd.DataFrame()
    
    try:    
        for file in files:
            try:
                if "7" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 4 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="7")

                    data_df.rename(columns={'Unnamed: 0': 'Total'}, inplace=True)
                    data_df = data_df.iloc[1:3, [1, 4]]
                    data_df['Total'] = data_df['Total'].astype(np.int64) 
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                print(f"Error while processing the sheet 4 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file)
            finally:    
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])                              
    except Exception as ex:
        print(f"Error while processing the sheet 4 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)
    finally:            
        nirf_df = nirf_df.groupby('Institution').sum('Total')
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Total number of PhD students enrolled'}, inplace=True)
    
    return nirf_df

# %%
process_sheet4()
# Out:
# Institution                            1 IR-O-U-0456  10 IR-O-U-0109  \
# Total number of PhD students enrolled           2841               0
#
# Institution                            100 IR-O-U-0470  11 IR-O-U-0500  \
# Total number of PhD students enrolled                0               0
#
# Institution                            12 IR-O-U-0013  13 IR-O-U-0108  \
# Total number of PhD students enrolled               0               0
#
# Institution                            14 IR-O-U-0234  15 IR-O-U-0120  \
# Total number of PhD students enrolled               0            3502
#
# Institution                            16 IR-O-U-0496  17 IR-O-U-0575  ...  \
# Total number of PhD students enrolled               0               0  ...
#
# Institution                            88 IR-O-U-0523  89 IR-O-U-0190  \
# Total number of PhD students enrolled               0             254
#
# Institution                            9 IR-O-U-0053  91 IR-O-U-0446  \
# Total number of PhD students enrolled              0            1144
#
# Institution                            92 IR-O-U-0055  93 IR-O-U-0577  \
# Total number of PhD students enrolled               0               0
#
# Institution                            94 IR-O-U-0136  95 IR-O-U-0642  \
# Total number of PhD students enrolled               0               0
#
# Institution                            97 IR-O-U-0003  99 IR-O-U-0686
# Total number of PhD students enrolled               0               0
#
# [1 rows x 83 columns]

# %%
def process_sheet4_1():
    nirf_df = pd.DataFrame()
    
    try:    
        for file in files:
            try:
                if "7" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 4 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="7")

                    data_df = data_df.iloc[[5], 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['Unnamed: 0'] = data_df['Unnamed: 0'].astype(np.float64)
                    data_df['Unnamed: 1'] = data_df['Unnamed: 1'].astype(np.float64)
                    data_df['Unnamed: 2'] = data_df['Unnamed: 2'].astype(np.float64)                    

                    data_df['Total'] = (data_df['Unnamed: 0'] + data_df['Unnamed: 1'] + data_df['Unnamed: 2'])/3              
                    data_df = data_df[['Total', 'Institution']]
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                print(f"Error while processing the sheet 4 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file)
            finally:    
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])            
    except Exception as ex:
        print(f"Error while processing the sheet 4 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:            
        nirf_df = nirf_df.set_index('Institution')
        nirf_df.sort_index(inplace=True)
        #nirf_df = nirf_df.groupby('Institution').mean('Total')
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Average Full Time PhD students graduated'}, inplace=True)
    
    return nirf_df

# %%
process_sheet4_1()
# Out:
# Institution                               1 IR-O-U-0456  10 IR-O-U-0109  \
# Average Full Time PhD students graduated     294.333333             0.0
#
# Institution                               100 IR-O-U-0470  11 IR-O-U-0500  \
# Average Full Time PhD students graduated              0.0             0.0
#
# Institution                               12 IR-O-U-0013  13 IR-O-U-0108  \
# Average Full Time PhD students graduated             0.0             0.0
#
# Institution                               14 IR-O-U-0234  15 IR-O-U-0120  \
# Average Full Time PhD students graduated             0.0      792.333333
#
# Institution                               16 IR-O-U-0496  17 IR-O-U-0575  ...  \
# Average Full Time PhD students graduated             0.0             0.0  ...
#
# Institution                               88 IR-O-U-0523  89 IR-O-U-0190  \
# Average Full Time PhD students graduated             0.0       54.666667
#
# Institution                               9 IR-O-U-0053  91 IR-O-U-0446  \
# Average Full Time PhD students graduated            0.0       71.333333
#
# Institution                               92 IR-O-U-0055  93 IR-O-U-0577  \
# Average Full Time PhD students graduated             0.0             0.0
#
# Institution                               94 IR-O-U-0136  95 IR-O-U-0642  \
# Average Full Time PhD students graduated             0.0             0.0
#
# Institution                               97 IR-O-U-0003  99 IR-O-U-0686
# Average Full Time PhD students graduated             0.0             0.0
#
# [1 rows x 83 columns]

# %%
def process_sheet4_2():
    nirf_df = pd.DataFrame()
    
    try:    
        for file in files:
            try:
                if "7" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 4 of the file: {file}")
    
                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="7")
    
                    data_df = data_df.iloc[[6], 1:]
                    
                    data_df['Unnamed: 0'] = data_df['Unnamed: 0'].astype(np.float64)
                    data_df['Unnamed: 1'] = data_df['Unnamed: 1'].astype(np.float64)
                    data_df['Unnamed: 2'] = data_df['Unnamed: 2'].astype(np.float64)
                    
                    data_df['Total'] = (data_df['Unnamed: 0'] + data_df['Unnamed: 1'] + data_df['Unnamed: 2'])/3              
                    data_df = data_df[['Total', 'Institution']]
                    data_df.fillna(0, inplace=True)
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                print(f"Error while processing the sheet 4 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file)
            finally:    
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])                            
    except Exception as ex:
        print(f"Error while processing the sheet 4 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)   
    finally:            
        nirf_df = nirf_df.set_index('Institution')
        nirf_df.sort_index(inplace=True)
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Average Part Time PhD students graduated'}, inplace=True)
    
    return nirf_df

# %%
process_sheet4_2()
# Out:
# Institution                               1 IR-O-U-0456  10 IR-O-U-0109  \
# Average Part Time PhD students graduated            5.0             0.0
#
# Institution                               100 IR-O-U-0470  11 IR-O-U-0500  \
# Average Part Time PhD students graduated              0.0             0.0
#
# Institution                               12 IR-O-U-0013  13 IR-O-U-0108  \
# Average Part Time PhD students graduated             0.0             0.0
#
# Institution                               14 IR-O-U-0234  15 IR-O-U-0120  \
# Average Part Time PhD students graduated             0.0             0.0
#
# Institution                               16 IR-O-U-0496  17 IR-O-U-0575  ...  \
# Average Part Time PhD students graduated             0.0             0.0  ...
#
# Institution                               88 IR-O-U-0523  89 IR-O-U-0190  \
# Average Part Time PhD students graduated             0.0             0.0
#
# Institution                               9 IR-O-U-0053  91 IR-O-U-0446  \
# Average Part Time PhD students graduated            0.0      135.666667
#
# Institution                               92 IR-O-U-0055  93 IR-O-U-0577  \
# Average Part Time PhD students graduated             0.0             0.0
#
# Institution                               94 IR-O-U-0136  95 IR-O-U-0642  \
# Average Part Time PhD students graduated             0.0             0.0
#
# Institution                               97 IR-O-U-0003  99 IR-O-U-0686
# Average Part Time PhD students graduated             0.0             0.0
#
# [1 rows x 83 columns]

# %% [markdown]
# ## Sheet 5

# %%
def get_empty_dataframe(file):
    data_df = pd.DataFrame({
                            '2022-23': [0],
                            '2021-22': [0],
                            '2020-21': [0],
                            'Institution': file.split('.')[0],
                            'Capex1': [0],
                            'Capex2': [0],
                            'Capex3': [0]
                        })
    return data_df

# %%
def process_sheet5():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "8" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 5 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="8")

                    data_df = data_df.iloc[2:, 1:]
                    data_df.fillna(0, inplace=True)

                    data_df['2022-23'] = data_df['2022-23'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2021-22'] = data_df['2021-22'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2020-21'] = data_df['2020-21'].str.split(r"(").str[0].astype(np.int64)

                    data_df['Capex1'] = round((np.sum(data_df['2022-23'])/100000),1)

                    data_df['Capex2'] = round((np.sum(data_df['2021-22'])/100000),1)

                    data_df['Capex3'] = round((np.sum(data_df['2020-21'])/100000),1)
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                print(f"Error while processing the sheet 5 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file)
            finally:
                nirf_df = pd.concat([nirf_df, data_df])       
    except Exception as ex:
        print(f"Error while processing the sheet 5 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)     
    finally:            
        nirf_df = nirf_df[['Capex1', 'Capex2', 'Capex3', 'Institution']].sort_values('Institution')
        nirf_df = nirf_df.set_index('Institution')
        nirf_df = nirf_df.groupby('Institution').head(1)
        nirf_df = nirf_df.transpose()      
    
    return nirf_df

# %%
process_sheet5()
# Out:
# Institution  1 IR-O-U-0456  10 IR-O-U-0109  100 IR-O-U-0470  11 IR-O-U-0500  \
# Capex1             62000.9             0.0              0.0             0.0
# Capex2             58448.8             0.0              0.0             0.0
# Capex3             17971.5             0.0              0.0             0.0
#
# Institution  12 IR-O-U-0013  13 IR-O-U-0108  14 IR-O-U-0234  15 IR-O-U-0120  \
# Capex1                  0.0             0.0             0.0          8351.6
# Capex2                  0.0             0.0             0.0          3624.7
# Capex3                  0.0             0.0             0.0          5881.7
#
# Institution  16 IR-O-U-0496  17 IR-O-U-0575  ...  88 IR-O-U-0523  \
# Capex1                  0.0             0.0  ...             0.0
# Capex2                  0.0             0.0  ...             0.0
# Capex3                  0.0             0.0  ...             0.0
#
# Institution  89 IR-O-U-0190  9 IR-O-U-0053  91 IR-O-U-0446  92 IR-O-U-0055  \
# Capex1                931.4            0.0         30713.2             0.0
# Capex2                225.9            0.0         22172.8             0.0
# Capex3                145.9            0.0         13208.8             0.0
#
# Institution  93 IR-O-U-0577  94 IR-O-U-0136  95 IR-O-U-0642  97 IR-O-U-0003  \
# Capex1                  0.0             0.0             0.0             0.0
# Capex2                  0.0             0.0             0.0             0.0
# Capex3                  0.0             0.0             0.0             0.0
#
# Institution  99 IR-O-U-0686
# Capex1                  0.0
# Capex2                  0.0
# Capex3                  0.0
#
# [3 rows x 83 columns]

# %% [markdown]
# ## Sheet 6

# %%
def get_empty_dataframe(file):    
    data_df = pd.DataFrame({
                        '2022-23': [0],
                        '2021-22': [0],
                        '2020-21': [0],
                        'Institution': file.split('.')[0],
                        'Opex1': [0],
                        'Opex2': [0],
                        'Opex3': [0]
                    })
    return data_df

# %%
def process_sheet6():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "9" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 6 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="9")

                    data_df = data_df.iloc[2:, 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['2022-23'] = data_df['2022-23'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2021-22'] = data_df['2021-22'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2020-21'] = data_df['2020-21'].str.split(r"(").str[0].astype(np.int64)

                    data_df['Opex1'] = round((np.sum(data_df['2022-23'])/1000000),1)

                    data_df['Opex2'] = round((np.sum(data_df['2021-22'])/1000000),1)

                    data_df['Opex3'] = round((np.sum(data_df['2020-21'])/1000000),1)                
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                print(f"Error while processing the sheet 6 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file)
            finally:
                nirf_df = pd.concat([nirf_df, data_df])               
    except Exception as ex:
        print(f"Error while processing the sheet 6 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)
    finally:            
        nirf_df = nirf_df[['Opex1', 'Opex2', 'Opex3', 'Institution']].sort_values('Institution')
        nirf_df = nirf_df.set_index('Institution')
        nirf_df = nirf_df.groupby('Institution').head(1)
        nirf_df = nirf_df.transpose() 
    
    return nirf_df

# %%
process_sheet6()
# Out:
# Institution  1 IR-O-U-0456  10 IR-O-U-0109  100 IR-O-U-0470  11 IR-O-U-0500  \
# Opex1              14246.1             0.0              0.0             0.0
# Opex2              14231.4             0.0              0.0             0.0
# Opex3              10328.5             0.0              0.0             0.0
#
# Institution  12 IR-O-U-0013  13 IR-O-U-0108  14 IR-O-U-0234  15 IR-O-U-0120  \
# Opex1                   0.0             0.0             0.0         13333.7
# Opex2                   0.0             0.0             0.0         10233.0
# Opex3                   0.0             0.0             0.0          6760.7
#
# Institution  16 IR-O-U-0496  17 IR-O-U-0575  ...  88 IR-O-U-0523  \
# Opex1                   0.0             0.0  ...             0.0
# Opex2                   0.0             0.0  ...             0.0
# Opex3                   0.0             0.0  ...             0.0
#
# Institution  89 IR-O-U-0190  9 IR-O-U-0053  91 IR-O-U-0446  92 IR-O-U-0055  \
# Opex1                 493.0            0.0          4999.1             0.0
# Opex2                 336.4            0.0          4925.8             0.0
# Opex3                 261.4            0.0          3093.8             0.0
#
# Institution  93 IR-O-U-0577  94 IR-O-U-0136  95 IR-O-U-0642  97 IR-O-U-0003  \
# Opex1                   0.0             0.0             0.0             0.0
# Opex2                   0.0             0.0             0.0             0.0
# Opex3                   0.0             0.0             0.0             0.0
#
# Institution  99 IR-O-U-0686
# Opex1                   0.0
# Opex2                   0.0
# Opex3                   0.0
#
# [3 rows x 83 columns]

# %% [markdown]
# ## Sheet 7

# %%
def get_empty_dataframe(file):         
    data_df = pd.DataFrame({
                        'Sponsored Average': [0], 
                        'Institution': file.split('.')[0]
                    })
    return data_df

# %%
def process_sheet7():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "10" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 7 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="10")

                    data_df = data_df.iloc[[0], 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['2022-23'] = data_df['2022-23'].astype(np.float64)
                    data_df['2021-22'] = data_df['2021-22'].astype(np.float64)
                    data_df['2020-21'] = data_df['2020-21'].astype(np.float64)

                    data_df['Sponsored Average'] = (data_df['2022-23'] + data_df['2021-22'] + data_df['2020-21'])/3
                    data_df = data_df[['Sponsored Average', 'Institution']]
                else:
                    data_df = get_empty_dataframe(file)
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file)
            finally:
                nirf_df = pd.concat([nirf_df, data_df])   
    except Exception as ex:
        print(f"Error while processing the sheet 7 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file)
    finally:            
        nirf_df = nirf_df.groupby('Institution').mean('Sponsored Average')
        nirf_df = nirf_df.transpose() 
    
    return nirf_df

# %%
process_sheet7()
# Out:
# Institution        1 IR-O-U-0456  10 IR-O-U-0109  100 IR-O-U-0470  \
# Sponsored Average     686.333333             0.0              0.0
#
# Institution        11 IR-O-U-0500  12 IR-O-U-0013  13 IR-O-U-0108  \
# Sponsored Average             0.0             0.0             0.0
#
# Institution        14 IR-O-U-0234  15 IR-O-U-0120  16 IR-O-U-0496  \
# Sponsored Average             0.0           477.0             0.0
#
# Institution        17 IR-O-U-0575  ...  88 IR-O-U-0523  89 IR-O-U-0190  \
# Sponsored Average             0.0  ...             0.0            10.0
#
# Institution        9 IR-O-U-0053  91 IR-O-U-0446  92 IR-O-U-0055  \
# Sponsored Average            0.0      156.666667             0.0
#
# Institution        93 IR-O-U-0577  94 IR-O-U-0136  95 IR-O-U-0642  \
# Sponsored Average             0.0             0.0             0.0
#
# Institution        97 IR-O-U-0003  99 IR-O-U-0686
# Sponsored Average             0.0             0.0
#
# [1 rows x 83 columns]

# %%
def process_sheet7_1():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "11" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 8 of the file: {file}")

                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="11")

                data_df = data_df.iloc[[0], 1:]
                data_df['2022-23'] = data_df['2022-23'].astype(np.float64)
                data_df['2021-22'] = data_df['2021-22'].astype(np.float64)
                data_df['2020-21'] = data_df['2020-21'].astype(np.float64)

                data_df['Consultancy Average'] = (data_df['2022-23'] + data_df['2021-22'] + data_df['2020-21'])/3
                data_df = data_df[['Consultancy Average', 'Institution']]
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])
    except Exception as ex:
        print(f"Error while processing the sheet 7 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:        
        nirf_df = nirf_df.groupby('Institution').mean('Consultancy Average')
        nirf_df = nirf_df.transpose()
    
    return nirf_df

# %%
process_sheet7_1()
# Out:
# Institution          1 IR-O-U-0456  10 IR-O-U-0109  100 IR-O-U-0470  \
# Consultancy Average    1034.666667             NaN              NaN
# Sponsored Average              NaN             0.0              0.0
#
# Institution          11 IR-O-U-0500  12 IR-O-U-0013  13 IR-O-U-0108  \
# Consultancy Average             NaN             NaN             NaN
# Sponsored Average               0.0             0.0             0.0
#
# Institution          14 IR-O-U-0234  15 IR-O-U-0120  16 IR-O-U-0496  \
# Consultancy Average             NaN        6.666667             NaN
# Sponsored Average               0.0             NaN             0.0
#
# Institution          17 IR-O-U-0575  ...  88 IR-O-U-0523  89 IR-O-U-0190  \
# Consultancy Average             NaN  ...             NaN        7.666667
# Sponsored Average               0.0  ...             0.0             NaN
#
# Institution          9 IR-O-U-0053  91 IR-O-U-0446  92 IR-O-U-0055  \
# Consultancy Average            NaN      320.333333             NaN
# Sponsored Average              0.0             NaN             0.0
#
# Institution          93 IR-O-U-0577  94 IR-O-U-0136  95 IR-O-U-0642  \
# Consultancy Average             NaN             NaN             NaN
# Sponsored Average               0.0             0.0             0.0
#
# Institution          97 IR-O-U-0003  99 IR-O-U-0686
# Consultancy Average             NaN             NaN
# Sponsored Average               0.0             0.0
#
# [2 rows x 83 columns]

# %%
def process_sheet7_2():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "12" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 8 of the file: {file}")

                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="12")

                data_df = data_df.iloc[[0], 1:]
                data_df['2022-23'] = data_df['2022-23'].astype(np.float64)
                data_df['2021-22'] = data_df['2021-22'].astype(np.float64)
                data_df['2020-21'] = data_df['2020-21'].astype(np.float64)

                data_df['Executive Average'] = (data_df['2022-23'] + data_df['2021-22'] + data_df['2020-21'])/3
                data_df = data_df[['Executive Average', 'Institution']]
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])
    except Exception as ex:
        print(f"Error while processing the sheet 7 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:        
        nirf_df = nirf_df.groupby('Institution').mean('Executive Average')
        nirf_df = nirf_df.transpose()
    
    return nirf_df

# %%
nirf_df = pd.DataFrame()

data = process_sheet0()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet1_1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet1_2()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet2()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet4()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet4_1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet4_2()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet5()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet6()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet7()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet7_1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet7_2()
nirf_df = pd.concat([nirf_df, data])

nirf_df = nirf_df.transpose()

nirf_df['capexperstudavg'] = (nirf_df['Capex1'] + \
                              nirf_df['Capex2'] + nirf_df['Capex3'])/ \
(3 * (nirf_df['Total sanctioned approved intake for all programs'] + nirf_df['Total number of PhD students enrolled']))

nirf_df['opexperstudavg'] = (nirf_df['Opex1'] + \
                              nirf_df['Opex2'] + nirf_df['Opex3'])/ \
(3 * (nirf_df['Total sanctioned approved intake for all programs'] + nirf_df['Total number of PhD students enrolled']))

nirf_df = nirf_df.transpose()

nirf_df.fillna(0, inplace=True)

nirf_df
# Out:
# Institution                                         1 IR-O-U-0456  \
# Total sanctioned approved intake for all programs    7.038000e+03
# Total number of students enrolled in all programs    7.397000e+03
# No. of students\rwho are not\rreceiving full\rt...   0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...   3.080000e+02
# No. of students_x000D_receiving full_x000D_tuit...   4.066000e+03
# No. of students_x000D_receiving full_x000D_tuit...   5.270000e+02
# No. of students\rreceiving full\rtuition fee\rr...   0.000000e+00
# No. of students\rreceiving full\rtuition fee\rr...   0.000000e+00
# No. of students\rreceiving full\rtuition fee\rr...   0.000000e+00
# Median salary                                        1.621147e+06
# Total number of PhD students enrolled                2.841000e+03
# Sponsored Average                                    0.000000e+00
# Average Full Time PhD students graduated             2.943333e+02
# Sponsored Average                                    0.000000e+00
# Average Part Time PhD students graduated             5.000000e+00
# Sponsored Average                                    0.000000e+00
# Capex1                                               6.200090e+04
# Capex2                                               5.844880e+04
# Capex3                                               1.797150e+04
# Opex1                                                1.424610e+04
# Opex2                                                1.423140e+04
# Opex3                                                1.032850e+04
# Sponsored Average                                    6.863333e+02
# Consultancy Average                                  1.034667e+03
# Sponsored Average                                    0.000000e+00
# Executive Average                                    7.366667e+01
# Sponsored Average                                    0.000000e+00
# capexperstudavg                                      4.670554e+00
# opexperstudavg                                       1.309377e+00
#
# Institution                                         10 IR-O-U-0109  \
# Total sanctioned approved intake for all programs      5118.000000
# Total number of students enrolled in all programs      5199.000000
# No. of students\rwho are not\rreceiving full\rt...     3463.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...      262.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# Median salary                                        666666.666667
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         100 IR-O-U-0470  \
# Total sanctioned approved intake for all programs       2700.000000
# Total number of students enrolled in all programs       2245.000000
# No. of students\rwho are not\rreceiving full\rt...       154.000000
# No. of students_x000D_receiving full_x000D_tuit...         0.000000
# No. of students_x000D_receiving full_x000D_tuit...         0.000000
# No. of students_x000D_receiving full_x000D_tuit...         0.000000
# No. of students\rreceiving full\rtuition fee\rr...      1773.000000
# No. of students\rreceiving full\rtuition fee\rr...       183.000000
# No. of students\rreceiving full\rtuition fee\rr...        90.000000
# Median salary                                         246934.666667
# Total number of PhD students enrolled                      0.000000
# Sponsored Average                                          0.000000
# Average Full Time PhD students graduated                   0.000000
# Sponsored Average                                          0.000000
# Average Part Time PhD students graduated                   0.000000
# Sponsored Average                                          0.000000
# Capex1                                                     0.000000
# Capex2                                                     0.000000
# Capex3                                                     0.000000
# Opex1                                                      0.000000
# Opex2                                                      0.000000
# Opex3                                                      0.000000
# Sponsored Average                                          0.000000
# Consultancy Average                                        0.000000
# Sponsored Average                                          0.000000
# Executive Average                                          0.000000
# Sponsored Average                                          0.000000
# capexperstudavg                                            0.000000
# opexperstudavg                                             0.000000
#
# Institution                                         11 IR-O-U-0500  \
# Total sanctioned approved intake for all programs          29439.0
# Total number of students enrolled in all programs          29466.0
# No. of students\rwho are not\rreceiving full\rt...         10523.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          7395.0
# No. of students\rreceiving full\rtuition fee\rr...            15.0
# No. of students\rreceiving full\rtuition fee\rr...           153.0
# Median salary                                             750000.0
# Total number of PhD students enrolled                          0.0
# Sponsored Average                                              0.0
# Average Full Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Average Part Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Capex1                                                         0.0
# Capex2                                                         0.0
# Capex3                                                         0.0
# Opex1                                                          0.0
# Opex2                                                          0.0
# Opex3                                                          0.0
# Sponsored Average                                              0.0
# Consultancy Average                                            0.0
# Sponsored Average                                              0.0
# Executive Average                                              0.0
# Sponsored Average                                              0.0
# capexperstudavg                                                0.0
# opexperstudavg                                                 0.0
#
# Institution                                         12 IR-O-U-0013  \
# Total sanctioned approved intake for all programs     3.008000e+03
# Total number of students enrolled in all programs     2.788000e+03
# No. of students\rwho are not\rreceiving full\rt...    6.950000e+02
# No. of students_x000D_receiving full_x000D_tuit...    0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...    0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...    0.000000e+00
# No. of students\rreceiving full\rtuition fee\rr...    1.290000e+02
# No. of students\rreceiving full\rtuition fee\rr...    6.760000e+02
# No. of students\rreceiving full\rtuition fee\rr...    2.000000e+00
# Median salary                                         1.908333e+06
# Total number of PhD students enrolled                 0.000000e+00
# Sponsored Average                                     0.000000e+00
# Average Full Time PhD students graduated              0.000000e+00
# Sponsored Average                                     0.000000e+00
# Average Part Time PhD students graduated              0.000000e+00
# Sponsored Average                                     0.000000e+00
# Capex1                                                0.000000e+00
# Capex2                                                0.000000e+00
# Capex3                                                0.000000e+00
# Opex1                                                 0.000000e+00
# Opex2                                                 0.000000e+00
# Opex3                                                 0.000000e+00
# Sponsored Average                                     0.000000e+00
# Consultancy Average                                   0.000000e+00
# Sponsored Average                                     0.000000e+00
# Executive Average                                     0.000000e+00
# Sponsored Average                                     0.000000e+00
# capexperstudavg                                       0.000000e+00
# opexperstudavg                                        0.000000e+00
#
# Institution                                         13 IR-O-U-0108  \
# Total sanctioned approved intake for all programs           8646.0
# Total number of students enrolled in all programs           8730.0
# No. of students\rwho are not\rreceiving full\rt...            29.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          5207.0
# No. of students\rreceiving full\rtuition fee\rr...          1901.0
# No. of students\rreceiving full\rtuition fee\rr...          1005.0
# Median salary                                             510000.0
# Total number of PhD students enrolled                          0.0
# Sponsored Average                                              0.0
# Average Full Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Average Part Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Capex1                                                         0.0
# Capex2                                                         0.0
# Capex3                                                         0.0
# Opex1                                                          0.0
# Opex2                                                          0.0
# Opex3                                                          0.0
# Sponsored Average                                              0.0
# Consultancy Average                                            0.0
# Sponsored Average                                              0.0
# Executive Average                                              0.0
# Sponsored Average                                              0.0
# capexperstudavg                                                0.0
# opexperstudavg                                                 0.0
#
# Institution                                         14 IR-O-U-0234  \
# Total sanctioned approved intake for all programs     26488.000000
# Total number of students enrolled in all programs     24376.000000
# No. of students\rwho are not\rreceiving full\rt...     1478.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...      123.000000
# No. of students\rreceiving full\rtuition fee\rr...     1450.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# Median salary                                        333333.333333
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         15 IR-O-U-0120  \
# Total sanctioned approved intake for all programs     23676.000000
# Total number of students enrolled in all programs     22894.000000
# No. of students\rwho are not\rreceiving full\rt...    10450.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...      331.000000
# No. of students\rreceiving full\rtuition fee\rr...     1382.000000
# No. of students\rreceiving full\rtuition fee\rr...        1.000000
# Median salary                                        500000.000000
# Total number of PhD students enrolled                  3502.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                792.333333
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                 8351.600000
# Capex2                                                 3624.700000
# Capex3                                                 5881.700000
# Opex1                                                 13333.700000
# Opex2                                                 10233.000000
# Opex3                                                  6760.700000
# Sponsored Average                                       477.000000
# Consultancy Average                                       6.666667
# Sponsored Average                                         0.000000
# Executive Average                                         2.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.219025
# opexperstudavg                                            0.371960
#
# Institution                                         16 IR-O-U-0496  \
# Total sanctioned approved intake for all programs          19380.0
# Total number of students enrolled in all programs          18782.0
# No. of students\rwho are not\rreceiving full\rt...          4171.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...          3873.0
# No. of students\rreceiving full\rtuition fee\rr...           855.0
# No. of students\rreceiving full\rtuition fee\rr...          2862.0
# Median salary                                             490262.0
# Total number of PhD students enrolled                          0.0
# Sponsored Average                                              0.0
# Average Full Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Average Part Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Capex1                                                         0.0
# Capex2                                                         0.0
# Capex3                                                         0.0
# Opex1                                                          0.0
# Opex2                                                          0.0
# Opex3                                                          0.0
# Sponsored Average                                              0.0
# Consultancy Average                                            0.0
# Sponsored Average                                              0.0
# Executive Average                                              0.0
# Sponsored Average                                              0.0
# capexperstudavg                                                0.0
# opexperstudavg                                                 0.0
#
# Institution                                         17 IR-O-U-0575  ...  \
# Total sanctioned approved intake for all programs     11548.000000  ...
# Total number of students enrolled in all programs     10394.000000  ...
# No. of students\rwho are not\rreceiving full\rt...      166.000000  ...
# No. of students_x000D_receiving full_x000D_tuit...        0.000000  ...
# No. of students_x000D_receiving full_x000D_tuit...        0.000000  ...
# No. of students_x000D_receiving full_x000D_tuit...        0.000000  ...
# No. of students\rreceiving full\rtuition fee\rr...     5436.000000  ...
# No. of students\rreceiving full\rtuition fee\rr...     1453.000000  ...
# No. of students\rreceiving full\rtuition fee\rr...      335.000000  ...
# Median salary                                        578333.333333  ...
# Total number of PhD students enrolled                     0.000000  ...
# Sponsored Average                                         0.000000  ...
# Average Full Time PhD students graduated                  0.000000  ...
# Sponsored Average                                         0.000000  ...
# Average Part Time PhD students graduated                  0.000000  ...
# Sponsored Average                                         0.000000  ...
# Capex1                                                    0.000000  ...
# Capex2                                                    0.000000  ...
# Capex3                                                    0.000000  ...
# Opex1                                                     0.000000  ...
# Opex2                                                     0.000000  ...
# Opex3                                                     0.000000  ...
# Sponsored Average                                         0.000000  ...
# Consultancy Average                                       0.000000  ...
# Sponsored Average                                         0.000000  ...
# Executive Average                                         0.000000  ...
# Sponsored Average                                         0.000000  ...
# capexperstudavg                                           0.000000  ...
# opexperstudavg                                            0.000000  ...
#
# Institution                                         88 IR-O-U-0523  \
# Total sanctioned approved intake for all programs      2859.000000
# Total number of students enrolled in all programs      2574.000000
# No. of students\rwho are not\rreceiving full\rt...      120.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...     1402.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# Median salary                                        966666.666667
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         89 IR-O-U-0190  \
# Total sanctioned approved intake for all programs      4121.000000
# Total number of students enrolled in all programs      3851.000000
# No. of students\rwho are not\rreceiving full\rt...      880.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...       69.000000
# No. of students\rreceiving full\rtuition fee\rr...       60.000000
# No. of students\rreceiving full\rtuition fee\rr...       12.000000
# Median salary                                        249666.666667
# Total number of PhD students enrolled                   254.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                 54.666667
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                  931.400000
# Capex2                                                  225.900000
# Capex3                                                  145.900000
# Opex1                                                   493.000000
# Opex2                                                   336.400000
# Opex3                                                   261.400000
# Sponsored Average                                        10.000000
# Consultancy Average                                       7.666667
# Sponsored Average                                         0.000000
# Executive Average                                         2.666667
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.099291
# opexperstudavg                                            0.083109
#
# Institution                                         9 IR-O-U-0053  \
# Total sanctioned approved intake for all programs    5.635000e+03
# Total number of students enrolled in all programs    5.678000e+03
# No. of students\rwho are not\rreceiving full\rt...   1.464000e+03
# No. of students_x000D_receiving full_x000D_tuit...   0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...   0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...   0.000000e+00
# No. of students\rreceiving full\rtuition fee\rr...   1.756000e+03
# No. of students\rreceiving full\rtuition fee\rr...   0.000000e+00
# No. of students\rreceiving full\rtuition fee\rr...   0.000000e+00
# Median salary                                        2.093333e+06
# Total number of PhD students enrolled                0.000000e+00
# Sponsored Average                                    0.000000e+00
# Average Full Time PhD students graduated             0.000000e+00
# Sponsored Average                                    0.000000e+00
# Average Part Time PhD students graduated             0.000000e+00
# Sponsored Average                                    0.000000e+00
# Capex1                                               0.000000e+00
# Capex2                                               0.000000e+00
# Capex3                                               0.000000e+00
# Opex1                                                0.000000e+00
# Opex2                                                0.000000e+00
# Opex3                                                0.000000e+00
# Sponsored Average                                    0.000000e+00
# Consultancy Average                                  0.000000e+00
# Sponsored Average                                    0.000000e+00
# Executive Average                                    0.000000e+00
# Sponsored Average                                    0.000000e+00
# capexperstudavg                                      0.000000e+00
# opexperstudavg                                       0.000000e+00
#
# Institution                                         91 IR-O-U-0446  \
# Total sanctioned approved intake for all programs     20629.000000
# Total number of students enrolled in all programs     19448.000000
# No. of students\rwho are not\rreceiving full\rt...     5897.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...      580.000000
# No. of students\rreceiving full\rtuition fee\rr...     1635.000000
# No. of students\rreceiving full\rtuition fee\rr...      758.000000
# Median salary                                        398333.333333
# Total number of PhD students enrolled                  1144.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                 71.333333
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                135.666667
# Sponsored Average                                         0.000000
# Capex1                                                30713.200000
# Capex2                                                22172.800000
# Capex3                                                13208.800000
# Opex1                                                  4999.100000
# Opex2                                                  4925.800000
# Opex3                                                  3093.800000
# Sponsored Average                                       156.666667
# Consultancy Average                                     320.333333
# Sponsored Average                                         0.000000
# Executive Average                                         5.666667
# Sponsored Average                                         0.000000
# capexperstudavg                                           1.011877
# opexperstudavg                                            0.199310
#
# Institution                                         92 IR-O-U-0055  \
# Total sanctioned approved intake for all programs     4.306000e+03
# Total number of students enrolled in all programs     4.040000e+03
# No. of students\rwho are not\rreceiving full\rt...    5.120000e+02
# No. of students_x000D_receiving full_x000D_tuit...    0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...    0.000000e+00
# No. of students_x000D_receiving full_x000D_tuit...    0.000000e+00
# No. of students\rreceiving full\rtuition fee\rr...    4.570000e+02
# No. of students\rreceiving full\rtuition fee\rr...    1.489000e+03
# No. of students\rreceiving full\rtuition fee\rr...    1.400000e+01
# Median salary                                         1.081667e+06
# Total number of PhD students enrolled                 0.000000e+00
# Sponsored Average                                     0.000000e+00
# Average Full Time PhD students graduated              0.000000e+00
# Sponsored Average                                     0.000000e+00
# Average Part Time PhD students graduated              0.000000e+00
# Sponsored Average                                     0.000000e+00
# Capex1                                                0.000000e+00
# Capex2                                                0.000000e+00
# Capex3                                                0.000000e+00
# Opex1                                                 0.000000e+00
# Opex2                                                 0.000000e+00
# Opex3                                                 0.000000e+00
# Sponsored Average                                     0.000000e+00
# Consultancy Average                                   0.000000e+00
# Sponsored Average                                     0.000000e+00
# Executive Average                                     0.000000e+00
# Sponsored Average                                     0.000000e+00
# capexperstudavg                                       0.000000e+00
# opexperstudavg                                        0.000000e+00
#
# Institution                                         93 IR-O-U-0577  \
# Total sanctioned approved intake for all programs      4604.000000
# Total number of students enrolled in all programs      4165.000000
# No. of students\rwho are not\rreceiving full\rt...       21.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...      323.000000
# No. of students\rreceiving full\rtuition fee\rr...     2355.000000
# No. of students\rreceiving full\rtuition fee\rr...       12.000000
# Median salary                                        953333.333333
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         94 IR-O-U-0136  \
# Total sanctioned approved intake for all programs      3540.000000
# Total number of students enrolled in all programs      3537.000000
# No. of students\rwho are not\rreceiving full\rt...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...     2144.000000
# No. of students\rreceiving full\rtuition fee\rr...       16.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# Median salary                                         53058.823529
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         95 IR-O-U-0642  \
# Total sanctioned approved intake for all programs      2595.000000
# Total number of students enrolled in all programs      2745.000000
# No. of students\rwho are not\rreceiving full\rt...       59.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...      289.000000
# No. of students\rreceiving full\rtuition fee\rr...       42.000000
# Median salary                                        870333.333333
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         97 IR-O-U-0003  \
# Total sanctioned approved intake for all programs      5240.000000
# Total number of students enrolled in all programs      5227.000000
# No. of students\rwho are not\rreceiving full\rt...      157.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students_x000D_receiving full_x000D_tuit...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...     5070.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# No. of students\rreceiving full\rtuition fee\rr...        0.000000
# Median salary                                        766666.666667
# Total number of PhD students enrolled                     0.000000
# Sponsored Average                                         0.000000
# Average Full Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Average Part Time PhD students graduated                  0.000000
# Sponsored Average                                         0.000000
# Capex1                                                    0.000000
# Capex2                                                    0.000000
# Capex3                                                    0.000000
# Opex1                                                     0.000000
# Opex2                                                     0.000000
# Opex3                                                     0.000000
# Sponsored Average                                         0.000000
# Consultancy Average                                       0.000000
# Sponsored Average                                         0.000000
# Executive Average                                         0.000000
# Sponsored Average                                         0.000000
# capexperstudavg                                           0.000000
# opexperstudavg                                            0.000000
#
# Institution                                         99 IR-O-U-0686
# Total sanctioned approved intake for all programs           1273.0
# Total number of students enrolled in all programs           1192.0
# No. of students\rwho are not\rreceiving full\rt...           413.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students_x000D_receiving full_x000D_tuit...             0.0
# No. of students\rreceiving full\rtuition fee\rr...           130.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...            90.0
# Median salary                                             820000.0
# Total number of PhD students enrolled                          0.0
# Sponsored Average                                              0.0
# Average Full Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Average Part Time PhD students graduated                       0.0
# Sponsored Average                                              0.0
# Capex1                                                         0.0
# Capex2                                                         0.0
# Capex3                                                         0.0
# Opex1                                                          0.0
# Opex2                                                          0.0
# Opex3                                                          0.0
# Sponsored Average                                              0.0
# Consultancy Average                                            0.0
# Sponsored Average                                              0.0
# Executive Average                                              0.0
# Sponsored Average                                              0.0
# capexperstudavg                                                0.0
# opexperstudavg                                                 0.0
#
# [29 rows x 83 columns]

# %%
nirf_df.to_excel(REPORT_FILE_DIRECTORY + "/PredictionReport.xlsx", freeze_panes=(1, 1),)
