# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# # Constants

# %%
PROCESSED_FILE_DIRECTORY = r"..\data\excel"

REPORT_FILE_DIRECTORY = r"..\data\report"

# %% [markdown]
# # Get Files

# %%
files = os.listdir(PROCESSED_FILE_DIRECTORY)

files = [f for f in files if os.path.isfile(PROCESSED_FILE_DIRECTORY + '/' + f)]

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Default Table Schema

# %%
def get_empty_dataframe(file, sheet_name):
    if sheet_name == "0":
        data_df = pd.DataFrame({'2021-22': [0],
                                            '2020-21': [0],
                                            '2019-20': [0],
                                            '2018-19': [0],
                                            '2017-18': [0],
                                            '2016-17': [0],
                                            'Institution': file.split('.')[0]
                                           })
    elif sheet_name == "1":
        data_df = pd.DataFrame({'Total Students': [0], 
                                            'Institution': file.split('.')[0]                    
                    })
    elif sheet_name == "2":
        data_df = pd.DataFrame({'Median salary UG': [0], 
                                            'Institution': file.split('.')[0]                    
                    })
    elif sheet_name == "3":
        data_df = pd.DataFrame({'Median salary PG': [0], 
                                            'Institution': file.split('.')[0]                    
                    })   
    elif sheet_name == "4":
        data_df = pd.DataFrame({'Total': [0], 
                                            'Institution': file.split('.')[0]
                    })    
    elif sheet_name == "5":
        data_df = pd.DataFrame({
                        '2021-22': [0],
                        '2020-21': [0],
                        '2019-20': [0],
                        'Institution': file.split('.')[0],
                        'Capex1': [0],
                        'Capex2': [0],
                        'Capex3': [0]
                    }) 
    elif sheet_name == "6":
        data_df = pd.DataFrame({
                        '2021-22': [0],
                        '2020-21': [0],
                        '2019-20': [0],
                        'Institution': file.split('.')[0],
                        'Opex1': [0],
                        'Opex2': [0],
                        'Opex3': [0]
                    })
    elif sheet_name == "7":
        data_df = pd.DataFrame({
                        'Sponsored Average': [0], 
                        'Institution': file.split('.')[0]
                    })  
    elif sheet_name == "8":
        data_df = pd.DataFrame({
                        'Consultancy Average': [0], 
                        'Institution': file.split('.')[0]
                    })    
    elif sheet_name == "10":
        data_df = pd.DataFrame({
                        'Answer': [None], 
                        'Institution': file.split('.')[0]
                    })        
    return data_df

# %% [markdown]
# ## Sheet 0

# %%
def process_sheet0():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:            
                #print(f"Processing the sheet 0 of the file: {file}")

                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="0")
                
                data_df = data_df.iloc[:, 1:]
                data_df.replace('-', 0, inplace=True)                

                data_df['2019-20'] = data_df['2019-20'].astype(np.int64)
                data_df['2018-19'] = data_df['2018-19'].astype(np.int64)
                data_df['2017-18'] = data_df['2017-18'].astype(np.int64)
                data_df['2016-17'] = data_df['2016-17'].astype(np.int64)

                data_df['Total'] = data_df['2021-22'] + data_df['2020-21'] + data_df['2019-20'] + \
                data_df['2018-19'] + data_df['2017-18'] + data_df['2016-17']    
            else:
                data_df = get_empty_dataframe(file, "0")
            
            data_df.fillna(0, inplace=True)
            nirf_df = pd.concat([nirf_df, data_df])           
    except Exception as ex:
        print(f"Error while processing the sheet 0 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "0")
    finally:
        nirf_df = nirf_df.groupby('Institution').sum('Total')[['Total']]
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Total sanctioned approved intake for all programs'}, inplace=True)    

    return nirf_df

# %% [markdown]
# ### Sheet 1

# %%
def process_sheet1():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 1 of the file: {file}")
                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="1")

                data_df = data_df[['Total Students', 'Institution']]
            else:
                data_df = get_empty_dataframe(file, "1")
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])                        
    except Exception as ex:
        print(f"Error while processing the sheet 1 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "1") 
    finally:                
        nirf_df = nirf_df.groupby('Institution').sum('Total Students')
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total Students': 'Total number of students enrolled in all programs'}, inplace=True)        
    
    return nirf_df

# %%
def process_sheet1_1():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 1 of the file: {file}")
                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="1")

                data_df = data_df.iloc[:, [7, 8, 13]]
                
                data_df['Total Students'] = data_df['Economically\rBackward\r(Including male\r& female)'] + \
                data_df['Socially\rChallenged\r(SC+ST+OBC\rIncluding male\r& female)']
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])                        
    except Exception as ex:
        print(f"Error while processing the sheet 1 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:                
        nirf_df = nirf_df.groupby('Institution').sum('Total Students')
        nirf_df = nirf_df.transpose()
        nirf_df = nirf_df.iloc[[-1], :]
        nirf_df.rename(index={'Total Students': 'Total number of economically socially challenged \
        students enrolled in all programs'}, inplace=True)        
    
    return nirf_df

# %%
def process_sheet1_2():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            if "1" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                #print(f"Processing the sheet 1 of the file: {file}")
                excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                data_df = pd.read_excel(excel_file, sheet_name="1")

                data_df = data_df.iloc[:, [9, 10, 11, 13]]
            else:
                data_df = get_empty_dataframe(file)
                
            data_df.fillna(0, inplace=True)        
            nirf_df = pd.concat([nirf_df, data_df])                        
    except Exception as ex:
        print(f"Error while processing the sheet 1 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file) 
    finally:                
        nirf_df = nirf_df.groupby('Institution').sum()
        nirf_df = nirf_df.transpose()
        #nirf_df.rename(index={'Total Students': 'Total number of economically socially challenged \
        #students enrolled in all programs'}, inplace=True)        
    
    return nirf_df

# %%
process_sheet1_2()
# Out:
# Institution                                         IR-P-C-10250  \
# No. of students\rreceiving full\rtuition fee\rr...           116
# No. of students\rreceiving full\rtuition fee\rr...            56
# No. of students\rreceiving full\rtuition fee\rr...            18
#
# Institution                                         IR-P-C-10283  \
# No. of students\rreceiving full\rtuition fee\rr...            53
# No. of students\rreceiving full\rtuition fee\rr...            30
# No. of students\rreceiving full\rtuition fee\rr...             0
#
# Institution                                         IR-P-C-11091  \
# No. of students\rreceiving full\rtuition fee\rr...            85
# No. of students\rreceiving full\rtuition fee\rr...             0
# No. of students\rreceiving full\rtuition fee\rr...             0
#
# Institution                                         IR-P-C-18900  \
# No. of students\rreceiving full\rtuition fee\rr...           132
# No. of students\rreceiving full\rtuition fee\rr...            32
# No. of students\rreceiving full\rtuition fee\rr...            13
#
# Institution                                         IR-P-C-19322  \
# No. of students\rreceiving full\rtuition fee\rr...            13
# No. of students\rreceiving full\rtuition fee\rr...             5
# No. of students\rreceiving full\rtuition fee\rr...             0
#
# Institution                                         IR-P-C-19611  \
# No. of students\rreceiving full\rtuition fee\rr...            95
# No. of students\rreceiving full\rtuition fee\rr...            45
# No. of students\rreceiving full\rtuition fee\rr...            15
#
# Institution                                         IR-P-C-19613  \
# No. of students\rreceiving full\rtuition fee\rr...           117
# No. of students\rreceiving full\rtuition fee\rr...            32
# No. of students\rreceiving full\rtuition fee\rr...             4
#
# Institution                                         IR-P-C-24007  \
# No. of students\rreceiving full\rtuition fee\rr...           263
# No. of students\rreceiving full\rtuition fee\rr...            13
# No. of students\rreceiving full\rtuition fee\rr...             2
#
# Institution                                         IR-P-C-24505  \
# No. of students\rreceiving full\rtuition fee\rr...             0
# No. of students\rreceiving full\rtuition fee\rr...             1
# No. of students\rreceiving full\rtuition fee\rr...             1
#
# Institution                                         IR-P-C-30768  ...  \
# No. of students\rreceiving full\rtuition fee\rr...            46  ...
# No. of students\rreceiving full\rtuition fee\rr...            58  ...
# No. of students\rreceiving full\rtuition fee\rr...             0  ...
#
# Institution                                         IR-P-U-0536  IR-P-U-0541  \
# No. of students\rreceiving full\rtuition fee\rr...           12            7
# No. of students\rreceiving full\rtuition fee\rr...            0            2
# No. of students\rreceiving full\rtuition fee\rr...            0            0
#
# Institution                                         IR-P-U-0562  IR-P-U-0575  \
# No. of students\rreceiving full\rtuition fee\rr...           62           59
# No. of students\rreceiving full\rtuition fee\rr...            5          127
# No. of students\rreceiving full\rtuition fee\rr...            1           11
#
# Institution                                         IR-P-U-0643  IR-P-U-0724  \
# No. of students\rreceiving full\rtuition fee\rr...          111          265
# No. of students\rreceiving full\rtuition fee\rr...           21            0
# No. of students\rreceiving full\rtuition fee\rr...            6            3
#
# Institution                                         IR-P-U-0747  IR-P-U-0811  \
# No. of students\rreceiving full\rtuition fee\rr...            6           45
# No. of students\rreceiving full\rtuition fee\rr...          102            0
# No. of students\rreceiving full\rtuition fee\rr...            2            0
#
# Institution                                         IR-P-U-0853  IR-P-U-0938
# No. of students\rreceiving full\rtuition fee\rr...           58            0
# No. of students\rreceiving full\rtuition fee\rr...          154            8
# No. of students\rreceiving full\rtuition fee\rr...            1            0
#
# [3 rows x 80 columns]

# %% [markdown]
# ## Sheet 2

# %%
def process_sheet2():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "2" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 2 of the file: {file}")
                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="2")
                    
                    columns = data_df.columns.to_list()
                    median_index = 0
                    institute_index = 0
                    
                    for index, element in enumerate(columns):
                        if element.split()[0] == 'Median':
                            median_index = index                            
                        elif element.split()[0] == 'Institution':
                            institute_index = index

                    data_df = pd.DataFrame({
                        'Median salary UG': data_df.iloc[:, median_index].values,
                        'Institution': data_df.iloc[:, institute_index].values
                    })

                    data_df['Median salary UG'] = data_df['Median salary UG'].str.split(r"(").str[0].astype(np.float64)
                else:
                    data_df = get_empty_dataframe(file, "2")
            except Exception as ex:
                data_df = get_empty_dataframe(file, "2")
            finally:  
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])           
    except Exception as ex:
        print(f"Error while processing the sheet 2 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "2")
    finally:            
        nirf_df = nirf_df.groupby('Institution').mean('Median salary UG')
        nirf_df = nirf_df.transpose()           
    
    return nirf_df

# %% [markdown]
# ## Sheet 3

# %%
def process_sheet3():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "3" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 2 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="3")

                    columns = data_df.columns.to_list()
                    median_index = 0
                    institute_index = 0

                    for index, element in enumerate(columns):
                        if element.split()[0] == 'Median':
                            median_index = index
                        elif element.split()[0] == 'Institution':
                            institute_index = index

                    data_df = pd.DataFrame({
                                'Median salary PG': data_df.iloc[:, median_index].values,
                                'Institution': data_df.iloc[:, institute_index].values
                            })

                    data_df['Median salary PG'] = data_df['Median salary PG'].str.split(r"(").str[0].astype(np.float64)
                else:
                    data_df = get_empty_dataframe(file, "3")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:    
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])
    except Exception as ex:
        print(f"Error while processing the sheet 3 of the file: {file}")
        print(str(ex))
        data_df = get_empty_dataframe(file, "3")        
    finally:
        nirf_df.fillna(0, inplace=True)
        nirf_df = nirf_df.groupby('Institution').mean('Median salary PG')
        nirf_df = nirf_df.transpose() 
    
    return nirf_df

# %% [markdown]
# ## Sheet 4

# %%
def process_sheet4():
    nirf_df = pd.DataFrame()
    
    try:    
        for file in files:
            try:
                if "4" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 4 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="4")

                    data_df.rename(columns={'Unnamed: 0': 'Total'}, inplace=True)
                    data_df = data_df.iloc[1:3, [1, 4]]
                    data_df['Total'] = data_df['Total'].astype(np.int64) 
                else:
                    data_df = get_empty_dataframe(file, "4")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:    
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])                              
    except Exception as ex:
        print(f"Error while processing the sheet 4 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "4")
    finally:            
        nirf_df = nirf_df.groupby('Institution').sum('Total')
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Total number of PhD students enrolled'}, inplace=True)
    
    return nirf_df

# %%
def process_sheet4_1():
    nirf_df = pd.DataFrame()
    
    try:    
        for file in files:
            try:
                if "4" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 4 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="4")

                    data_df = data_df.iloc[[1], 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['Unnamed: 0'] = data_df['Unnamed: 0'].astype(np.int64)
                    data_df['Unnamed: 1'] = data_df['Unnamed: 1'].astype(np.int64)
                    data_df['Unnamed: 2'] = data_df['Unnamed: 2'].astype(np.int64)                    

                    data_df['Total'] = (data_df['Unnamed: 0'] + data_df['Unnamed: 1'] + data_df['Unnamed: 2'])/3              
                    data_df = data_df[['Total', 'Institution']]
                else:
                    data_df = get_empty_dataframe(file, "4")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:    
                data_df.fillna(0, inplace=True)
                nirf_df = pd.concat([nirf_df, data_df])            
    except Exception as ex:
        print(f"Error while processing the sheet 4 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "4") 
    finally:            
        nirf_df = nirf_df.set_index('Institution')
        nirf_df.sort_index(inplace=True)
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Average Full Time PhD students graduated'}, inplace=True)
    
    return nirf_df

# %%
def process_sheet4_2():
    nirf_df = pd.DataFrame()
    
    try:    
        for file in files:
            try:
                if "4" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 4 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="4")

                    data_df = data_df.iloc[[6], 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['Unnamed: 0'] = data_df['Unnamed: 0'].astype(np.int64)
                    data_df['Unnamed: 1'] = data_df['Unnamed: 1'].astype(np.int64)
                    data_df['Unnamed: 2'] = data_df['Unnamed: 2'].astype(np.int64)

                    data_df['Total'] = (data_df['Unnamed: 0'] + data_df['Unnamed: 1'] + data_df['Unnamed: 2'])/3              
                    data_df = data_df[['Total', 'Institution']]
                    data_df.fillna(0, inplace=True)
                else:
                    data_df = get_empty_dataframe(file, "4")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:    
                nirf_df = pd.concat([nirf_df, data_df])             
    except Exception as ex:
        print(f"Error while processing the sheet 4 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "4")    
    finally:            
        nirf_df = nirf_df.set_index('Institution')
        nirf_df.sort_index(inplace=True)
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Total': 'Average Part Time PhD students graduated'}, inplace=True)
    
    return nirf_df

# %% [markdown]
# ## Sheet 5

# %%
def process_sheet5():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "5" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 5 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="5")

                    data_df = data_df.iloc[2:, 1:]
                    data_df.fillna(0, inplace=True)

                    data_df['2021-22'] = data_df['2021-22'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2020-21'] = data_df['2020-21'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2019-20'] = data_df['2019-20'].str.split(r"(").str[0].astype(np.int64)

                    data_df['Capex1'] = round((np.sum(data_df['2021-22'])/100000),1)

                    data_df['Capex2'] = round((np.sum(data_df['2020-21'])/100000),1)

                    data_df['Capex3'] = round((np.sum(data_df['2019-20'])/100000),1)
                else:
                    data_df = get_empty_dataframe(file, "5")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:
                nirf_df = pd.concat([nirf_df, data_df])       
    except Exception as ex:
        print(f"Error while processing the sheet 5 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "5")     
    finally:            
        nirf_df = nirf_df[['Capex1', 'Capex2', 'Capex3', 'Institution']].sort_values('Institution')
        nirf_df = nirf_df.set_index('Institution')
        nirf_df = nirf_df.groupby('Institution').head(1)
        nirf_df = nirf_df.transpose()      
    
    return nirf_df

# %% [markdown]
# ## Sheet 6

# %%
def process_sheet6():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "6" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 6 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="6")

                    data_df = data_df.iloc[2:, 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['2021-22'] = data_df['2021-22'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2020-21'] = data_df['2020-21'].str.split(r"(").str[0].astype(np.int64)

                    data_df['2019-20'] = data_df['2019-20'].str.split(r"(").str[0].astype(np.int64)

                    data_df['Opex1'] = round((np.sum(data_df['2021-22'])/1000000),1)

                    data_df['Opex2'] = round((np.sum(data_df['2020-21'])/1000000),1)

                    data_df['Opex3'] = round((np.sum(data_df['2019-20'])/1000000),1)                
                else:
                    data_df = get_empty_dataframe(file, "6")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:
                nirf_df = pd.concat([nirf_df, data_df])               
    except Exception as ex:
        print(f"Error while processing the sheet 6 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "6")
    finally:            
        nirf_df = nirf_df[['Opex1', 'Opex2', 'Opex3', 'Institution']].sort_values('Institution')
        nirf_df = nirf_df.set_index('Institution')
        nirf_df = nirf_df.groupby('Institution').head(1)
        nirf_df = nirf_df.transpose() 
    
    return nirf_df

# %% [markdown]
# ## Sheet 7

# %%
def process_sheet7():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "7" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 7 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="7")

                    data_df = data_df.iloc[[2], 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['2021-22'] = data_df['2021-22'].astype(np.float64)
                    data_df['2020-21'] = data_df['2020-21'].astype(np.float64)
                    data_df['2019-20'] = data_df['2019-20'].astype(np.float64)

                    data_df['Sponsored Average'] = (data_df['2021-22'] + data_df['2020-21'] + data_df['2019-20'])/3
                    data_df = data_df[['Sponsored Average', 'Institution']]
                else:
                    data_df = get_empty_dataframe(file, "7")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:
                nirf_df = pd.concat([nirf_df, data_df])   
    except Exception as ex:
        print(f"Error while processing the sheet 7 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "7")
    finally:            
        nirf_df = nirf_df.groupby('Institution').mean('Sponsored Average')
        nirf_df = nirf_df.transpose() 
    
    return nirf_df

# %% [markdown]
# ## Sheet 8

# %%
def process_sheet8():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "8" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet 8 of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="8")

                    data_df = data_df.iloc[[2], 1:]
                    data_df.fillna(0, inplace=True)
                    
                    data_df['2021-22'] = data_df['2021-22'].astype(np.float64)
                    data_df['2020-21'] = data_df['2020-21'].astype(np.float64)
                    data_df['2019-20'] = data_df['2019-20'].astype(np.float64)

                    data_df['Consultancy Average'] = (data_df['2021-22'] + data_df['2020-21'] + data_df['2019-20'])/3
                    data_df = data_df[['Consultancy Average', 'Institution']]
                else:
                    data_df = get_empty_dataframe(file, "8")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:
                nirf_df = pd.concat([nirf_df, data_df]) 
    except Exception as ex:
        print(f"Error while processing the sheet 8 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "8") 
    finally:        
        nirf_df = nirf_df.groupby('Institution').mean('Consultancy Average')
        nirf_df = nirf_df.transpose()
    
    return nirf_df

# %% [markdown]
# ## Sheet 10

# %%
def process_sheet10():
    nirf_df = pd.DataFrame()
    
    try:
        for file in files:
            try:
                if "10" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
                    #print(f"Processing the sheet {sheet_name} of the file: {file}")

                    excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
                    data_df = pd.read_excel(excel_file, sheet_name="10")
                    data_df.fillna(0, inplace=True)
                else:
                    data_df = get_empty_dataframe(file, "10")
            except Exception as ex:
                print(f"Error while processing the sheet 3 of the file: {file}")
                print(str(ex))
                data_df = get_empty_dataframe(file, "3")
            finally:
                nirf_df = pd.concat([nirf_df, data_df])
    except Exception as ex:
        print(f"Error while processing the sheet 10 of the file: {file}")
        print(str(ex))
        nirf_df = get_empty_dataframe(file, "10")
    finally:
        nirf_df = nirf_df[['Answer', 'Institution']].sort_values('Institution')
        nirf_df = nirf_df.set_index('Institution')
        nirf_df.sort_index(inplace=True)
        nirf_df = nirf_df.transpose()
        nirf_df.rename(index={'Answer': 'Number of faculty members'}, inplace=True)
        
    return nirf_df

# %%
nirf_df = pd.DataFrame()

data = process_sheet0()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet1_1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet1_2()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet2()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet3()
nirf_df = pd.concat([nirf_df, data])

nirf_df = nirf_df.transpose()
nirf_df['Median Salary'] = (nirf_df['Median salary UG'] + nirf_df['Median salary PG'])/2
nirf_df = nirf_df.transpose()

data = process_sheet4()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet4_1()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet4_2()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet5()
nirf_df = pd.concat([nirf_df, data])

nirf_df = nirf_df.transpose()
nirf_df['capexperstudavg'] = (nirf_df['Capex1'] + \
                              nirf_df['Capex2'] + nirf_df['Capex3'])/ \
(3 * (nirf_df['Total sanctioned approved intake for all programs'] + nirf_df['Total number of PhD students enrolled']))
nirf_df = nirf_df.transpose()

data = process_sheet6()
nirf_df = pd.concat([nirf_df, data])

nirf_df = nirf_df.transpose()
nirf_df['opexperstudavg'] = (nirf_df['Opex1'] + \
                              nirf_df['Opex2'] + nirf_df['Opex3'])/ \
(3 * (nirf_df['Total sanctioned approved intake for all programs'] + nirf_df['Total number of PhD students enrolled']))
nirf_df = nirf_df.transpose()

data = process_sheet7()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet8()
nirf_df = pd.concat([nirf_df, data])

data = process_sheet10()
nirf_df = pd.concat([nirf_df, data])

nirf_df
# Out:
# Error while processing the sheet 3 of the file: IR-P-C-19322.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-19611.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-24007.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-24505.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-35430.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-39486.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-40080.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-409.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-45585.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-C-45757.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-I-1248.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-I-1335.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-U-0473.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-U-0724.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Error while processing the sheet 3 of the file: IR-P-U-0747.xlsx
# could not convert string to float: 'Median salary of\rplaced graduates per\rannum'
# Institution                                           IR-P-C-10250  \
# Total sanctioned approved intake for all programs            358.0
# Total number of students enrolled in all programs            336.0
# Total number of economically socially challenge...           259.0
# No. of students\rreceiving full\rtuition fee\rr...           116.0
# No. of students\rreceiving full\rtuition fee\rr...            56.0
# No. of students\rreceiving full\rtuition fee\rr...            18.0
# Median salary UG                                     316333.333333
# Median salary PG                                     345333.333333
# Median Salary                                        330833.333333
# Total number of PhD students enrolled                         36.0
# Average Full Time PhD students graduated                  4.666667
# Average Part Time PhD students graduated                  3.333333
# Capex1                                                        59.4
# Capex2                                                        54.3
# Capex3                                                        21.5
# capexperstudavg                                           0.114382
# Opex1                                                         43.1
# Opex2                                                         40.5
# Opex3                                                         23.1
# opexperstudavg                                            0.090271
# Sponsored Average                                   2707561.333333
# Consultancy Average                                 1967025.333333
# Number of faculty members                                       53
#
# Institution                                           IR-P-C-10283  \
# Total sanctioned approved intake for all programs            454.0
# Total number of students enrolled in all programs            487.0
# Total number of economically socially challenge...            83.0
# No. of students\rreceiving full\rtuition fee\rr...            53.0
# No. of students\rreceiving full\rtuition fee\rr...            30.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# Median salary UG                                          370000.0
# Median salary PG                                     516666.666667
# Median Salary                                        443333.333333
# Total number of PhD students enrolled                         15.0
# Average Full Time PhD students graduated                       0.0
# Average Part Time PhD students graduated                       5.0
# Capex1                                                        79.2
# Capex2                                                        61.3
# Capex3                                                        32.2
# capexperstudavg                                           0.122743
# Opex1                                                         98.0
# Opex2                                                         66.8
# Opex3                                                         68.4
# opexperstudavg                                            0.165743
# Sponsored Average                                   1705531.333333
# Consultancy Average                                 4185454.333333
# Number of faculty members                                       60
#
# Institution                                          IR-P-C-11091  \
# Total sanctioned approved intake for all programs           360.0
# Total number of students enrolled in all programs           412.0
# Total number of economically socially challenge...          285.0
# No. of students\rreceiving full\rtuition fee\rr...           85.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# Median salary UG                                    211333.333333
# Median salary PG                                         315028.0
# Median Salary                                       263180.666667
# Total number of PhD students enrolled                        32.0
# Average Full Time PhD students graduated                 2.666667
# Average Part Time PhD students graduated                      3.0
# Capex1                                                       45.1
# Capex2                                                       21.9
# Capex3                                                       12.5
# capexperstudavg                                          0.067602
# Opex1                                                        50.8
# Opex2                                                        42.0
# Opex3                                                        48.2
# opexperstudavg                                           0.119898
# Sponsored Average                                   581252.666667
# Consultancy Average                                       31075.0
# Number of faculty members                                      28
#
# Institution                                           IR-P-C-18900  \
# Total sanctioned approved intake for all programs            495.0
# Total number of students enrolled in all programs            577.0
# Total number of economically socially challenge...           360.0
# No. of students\rreceiving full\rtuition fee\rr...           132.0
# No. of students\rreceiving full\rtuition fee\rr...            32.0
# No. of students\rreceiving full\rtuition fee\rr...            13.0
# Median salary UG                                     403333.333333
# Median salary PG                                     403333.333333
# Median Salary                                        403333.333333
# Total number of PhD students enrolled                          8.0
# Average Full Time PhD students graduated                  2.666667
# Average Part Time PhD students graduated                  0.333333
# Capex1                                                        72.8
# Capex2                                                        56.6
# Capex3                                                        43.2
# capexperstudavg                                            0.11438
# Opex1                                                         40.4
# Opex2                                                         35.1
# Opex3                                                         38.1
# opexperstudavg                                            0.075282
# Sponsored Average                                        2683983.0
# Consultancy Average                                 1581975.666667
# Number of faculty members                                       55
#
# Institution                                           IR-P-C-19322  \
# Total sanctioned approved intake for all programs            745.0
# Total number of students enrolled in all programs            740.0
# Total number of economically socially challenge...           710.0
# No. of students\rreceiving full\rtuition fee\rr...            13.0
# No. of students\rreceiving full\rtuition fee\rr...             5.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# Median salary UG                                          188000.0
# Median salary PG                                               0.0
# Median Salary                                              94000.0
# Total number of PhD students enrolled                         39.0
# Average Full Time PhD students graduated                  8.666667
# Average Part Time PhD students graduated                       1.0
# Capex1                                                       103.9
# Capex2                                                        61.7
# Capex3                                                        67.1
# capexperstudavg                                           0.098937
# Opex1                                                         94.5
# Opex2                                                         79.6
# Opex3                                                         87.4
# opexperstudavg                                            0.111182
# Sponsored Average                                   2375730.333333
# Consultancy Average                                 1013862.333333
# Number of faculty members                                       65
#
# Institution                                           IR-P-C-19611  \
# Total sanctioned approved intake for all programs            670.0
# Total number of students enrolled in all programs            638.0
# Total number of economically socially challenge...           485.0
# No. of students\rreceiving full\rtuition fee\rr...            95.0
# No. of students\rreceiving full\rtuition fee\rr...            45.0
# No. of students\rreceiving full\rtuition fee\rr...            15.0
# Median salary UG                                          258000.0
# Median salary PG                                               0.0
# Median Salary                                             129000.0
# Total number of PhD students enrolled                          2.0
# Average Full Time PhD students graduated                       0.0
# Average Part Time PhD students graduated                       0.0
# Capex1                                                        26.7
# Capex2                                                         9.5
# Capex3                                                        72.3
# capexperstudavg                                           0.053819
# Opex1                                                         69.7
# Opex2                                                         64.1
# Opex3                                                         55.3
# opexperstudavg                                              0.0938
# Sponsored Average                                   2531666.666667
# Consultancy Average                                      1600000.0
# Number of faculty members                                       51
#
# Institution                                           IR-P-C-19613  \
# Total sanctioned approved intake for all programs            484.0
# Total number of students enrolled in all programs            477.0
# Total number of economically socially challenge...           388.0
# No. of students\rreceiving full\rtuition fee\rr...           117.0
# No. of students\rreceiving full\rtuition fee\rr...            32.0
# No. of students\rreceiving full\rtuition fee\rr...             4.0
# Median salary UG                                          190000.0
# Median salary PG                                          212000.0
# Median Salary                                             201000.0
# Total number of PhD students enrolled                          9.0
# Average Full Time PhD students graduated                       0.0
# Average Part Time PhD students graduated                  2.666667
# Capex1                                                        18.1
# Capex2                                                        11.8
# Capex3                                                        23.8
# capexperstudavg                                           0.036308
# Opex1                                                         51.6
# Opex2                                                         31.9
# Opex3                                                         46.1
# opexperstudavg                                            0.087627
# Sponsored Average                                    893287.666667
# Consultancy Average                                 2107966.333333
# Number of faculty members                                       36
#
# Institution                                           IR-P-C-24007  \
# Total sanctioned approved intake for all programs            748.0
# Total number of students enrolled in all programs            645.0
# Total number of economically socially challenge...           645.0
# No. of students\rreceiving full\rtuition fee\rr...           263.0
# No. of students\rreceiving full\rtuition fee\rr...            13.0
# No. of students\rreceiving full\rtuition fee\rr...             2.0
# Median salary UG                                     198333.333333
# Median salary PG                                               0.0
# Median Salary                                         99166.666667
# Total number of PhD students enrolled                         31.0
# Average Full Time PhD students graduated                  2.666667
# Average Part Time PhD students graduated                  1.666667
# Capex1                                                        20.6
# Capex2                                                         7.3
# Capex3                                                        10.6
# capexperstudavg                                           0.016474
# Opex1                                                         51.3
# Opex2                                                         55.6
# Opex3                                                         58.1
# opexperstudavg                                            0.070603
# Sponsored Average                                   1882333.333333
# Consultancy Average                                  764531.333333
# Number of faculty members                                       59
#
# Institution                                           IR-P-C-24505  \
# Total sanctioned approved intake for all programs            680.0
# Total number of students enrolled in all programs            676.0
# Total number of economically socially challenge...           309.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...             1.0
# No. of students\rreceiving full\rtuition fee\rr...             1.0
# Median salary UG                                          231000.0
# Median salary PG                                               0.0
# Median Salary                                             115500.0
# Total number of PhD students enrolled                         30.0
# Average Full Time PhD students graduated                  8.666667
# Average Part Time PhD students graduated                  0.333333
# Capex1                                                        17.8
# Capex2                                                        49.1
# Capex3                                                        30.0
# capexperstudavg                                           0.045493
# Opex1                                                         76.2
# Opex2                                                         68.1
# Opex3                                                         72.1
# opexperstudavg                                            0.101596
# Sponsored Average                                         550784.0
# Consultancy Average                                 3143946.666667
# Number of faculty members                                       53
#
# Institution                                            IR-P-C-30768  ...  \
# Total sanctioned approved intake for all programs             260.0  ...
# Total number of students enrolled in all programs             274.0  ...
# Total number of economically socially challenge...            104.0  ...
# No. of students\rreceiving full\rtuition fee\rr...             46.0  ...
# No. of students\rreceiving full\rtuition fee\rr...             58.0  ...
# No. of students\rreceiving full\rtuition fee\rr...              0.0  ...
# Median salary UG                                      361666.666667  ...
# Median salary PG                                      486666.666667  ...
# Median Salary                                         424166.666667  ...
# Total number of PhD students enrolled                           8.0  ...
# Average Full Time PhD students graduated                        0.0  ...
# Average Part Time PhD students graduated                        1.0  ...
# Capex1                                                        342.7  ...
# Capex2                                                        274.6  ...
# Capex3                                                        438.3  ...
# capexperstudavg                                            1.312935  ...
# Opex1                                                          91.4  ...
# Opex2                                                          78.1  ...
# Opex3                                                          71.3  ...
# opexperstudavg                                             0.299502  ...
# Sponsored Average                                   10796478.333333  ...
# Consultancy Average                                             0.0  ...
# Number of faculty members                                        18  ...
#
# Institution                                            IR-P-U-0536  \
# Total sanctioned approved intake for all programs            261.0
# Total number of students enrolled in all programs            237.0
# Total number of economically socially challenge...            23.0
# No. of students\rreceiving full\rtuition fee\rr...            12.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# No. of students\rreceiving full\rtuition fee\rr...             0.0
# Median salary UG                                     238866.666667
# Median salary PG                                           96000.0
# Median Salary                                        167433.333333
# Total number of PhD students enrolled                         39.0
# Average Full Time PhD students graduated                      13.0
# Average Part Time PhD students graduated                       0.0
# Capex1                                                        27.4
# Capex2                                                        28.2
# Capex3                                                        18.3
# capexperstudavg                                           0.082111
# Opex1                                                         25.4
# Opex2                                                         21.3
# Opex3                                                         35.4
# opexperstudavg                                            0.091222
# Sponsored Average                                   1245397.333333
# Consultancy Average                                            0.0
# Number of faculty members                                       24
#
# Institution                                          IR-P-U-0541 IR-P-U-0562  \
# Total sanctioned approved intake for all programs          280.0       213.0
# Total number of students enrolled in all programs          290.0       218.0
# Total number of economically socially challenge...         198.0        80.0
# No. of students\rreceiving full\rtuition fee\rr...           7.0        62.0
# No. of students\rreceiving full\rtuition fee\rr...           2.0         5.0
# No. of students\rreceiving full\rtuition fee\rr...           0.0         1.0
# Median salary UG                                    21621.621622    250000.0
# Median salary PG                                             0.0    400000.0
# Median Salary                                       10810.810811    325000.0
# Total number of PhD students enrolled                        0.0        31.0
# Average Full Time PhD students graduated                     0.0   10.333333
# Average Part Time PhD students graduated                     0.0         0.0
# Capex1                                                       0.0        21.7
# Capex2                                                       0.0         3.2
# Capex3                                                       0.0         3.6
# capexperstudavg                                              0.0    0.038934
# Opex1                                                        0.0        22.1
# Opex2                                                        0.0        26.6
# Opex3                                                        0.0        21.2
# opexperstudavg                                               0.0    0.095492
# Sponsored Average                                            0.0         0.0
# Consultancy Average                                          0.0         0.0
# Number of faculty members                                   None          18
#
# Institution                                             IR-P-U-0575  \
# Total sanctioned approved intake for all programs             336.0
# Total number of students enrolled in all programs             305.0
# Total number of economically socially challenge...            298.0
# No. of students\rreceiving full\rtuition fee\rr...             59.0
# No. of students\rreceiving full\rtuition fee\rr...            127.0
# No. of students\rreceiving full\rtuition fee\rr...             11.0
# Median salary UG                                      396921.666667
# Median salary PG                                      387066.666667
# Median Salary                                         391994.166667
# Total number of PhD students enrolled                          66.0
# Average Full Time PhD students graduated                       22.0
# Average Part Time PhD students graduated                        0.0
# Capex1                                                         71.0
# Capex2                                                        150.0
# Capex3                                                         38.0
# capexperstudavg                                             0.21476
# Opex1                                                          88.4
# Opex2                                                          46.1
# Opex3                                                          37.8
# opexperstudavg                                             0.142869
# Sponsored Average                                   11314687.666667
# Consultancy Average                                        342554.0
# Number of faculty members                                        30
#
# Institution                                            IR-P-U-0643  \
# Total sanctioned approved intake for all programs            427.0
# Total number of students enrolled in all programs            398.0
# Total number of economically socially challenge...           166.0
# No. of students\rreceiving full\rtuition fee\rr...           111.0
# No. of students\rreceiving full\rtuition fee\rr...            21.0
# No. of students\rreceiving full\rtuition fee\rr...             6.0
# Median salary UG                                     247333.333333
# Median salary PG                                     328666.666667
# Median Salary                                             288000.0
# Total number of PhD students enrolled                         25.0
# Average Full Time PhD students graduated                       4.0
# Average Part Time PhD students graduated                       1.0
# Capex1                                                       106.1
# Capex2                                                       100.4
# Capex3                                                       101.8
# capexperstudavg                                            0.22736
# Opex1                                                         45.3
# Opex2                                                         39.7
# Opex3                                                         41.2
# opexperstudavg                                            0.093068
# Sponsored Average                                   2525146.666667
# Consultancy Average                                 3887713.333333
# Number of faculty members                                       29
#
# Institution                                           IR-P-U-0724  \
# Total sanctioned approved intake for all programs           718.0
# Total number of students enrolled in all programs           664.0
# Total number of economically socially challenge...          626.0
# No. of students\rreceiving full\rtuition fee\rr...          265.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# No. of students\rreceiving full\rtuition fee\rr...            3.0
# Median salary UG                                    301666.666667
# Median salary PG                                              0.0
# Median Salary                                       150833.333333
# Total number of PhD students enrolled                        15.0
# Average Full Time PhD students graduated                 2.333333
# Average Part Time PhD students graduated                 0.666667
# Capex1                                                       38.5
# Capex2                                                       31.8
# Capex3                                                       18.8
# capexperstudavg                                          0.040518
# Opex1                                                        81.4
# Opex2                                                        84.1
# Opex3                                                        79.2
# opexperstudavg                                           0.111278
# Sponsored Average                                       1360000.0
# Consultancy Average                                       79745.0
# Number of faculty members                                      40
#
# Institution                                             IR-P-U-0747  \
# Total sanctioned approved intake for all programs             520.0
# Total number of students enrolled in all programs             519.0
# Total number of economically socially challenge...            152.0
# No. of students\rreceiving full\rtuition fee\rr...              6.0
# No. of students\rreceiving full\rtuition fee\rr...            102.0
# No. of students\rreceiving full\rtuition fee\rr...              2.0
# Median salary UG                                           382000.0
# Median salary PG                                                0.0
# Median Salary                                              191000.0
# Total number of PhD students enrolled                          77.0
# Average Full Time PhD students graduated                  18.333333
# Average Part Time PhD students graduated                   6.666667
# Capex1                                                        446.2
# Capex2                                                        364.6
# Capex3                                                        181.1
# capexperstudavg                                            0.553825
# Opex1                                                         120.2
# Opex2                                                         111.6
# Opex3                                                          77.5
# opexperstudavg                                             0.172697
# Sponsored Average                                        46452362.0
# Consultancy Average                                 17626806.666667
# Number of faculty members                                        51
#
# Institution                                             IR-P-U-0811  \
# Total sanctioned approved intake for all programs             276.0
# Total number of students enrolled in all programs             276.0
# Total number of economically socially challenge...             75.0
# No. of students\rreceiving full\rtuition fee\rr...             45.0
# No. of students\rreceiving full\rtuition fee\rr...              0.0
# No. of students\rreceiving full\rtuition fee\rr...              0.0
# Median salary UG                                       66666.666667
# Median salary PG                                           260000.0
# Median Salary                                         163333.333333
# Total number of PhD students enrolled                          19.0
# Average Full Time PhD students graduated                   3.333333
# Average Part Time PhD students graduated                        0.0
# Capex1                                                          0.0
# Capex2                                                          1.0
# Capex3                                                         59.4
# capexperstudavg                                            0.068249
# Opex1                                                          11.4
# Opex2                                                          10.6
# Opex3                                                           9.8
# opexperstudavg                                             0.035932
# Sponsored Average                                   11548733.333333
# Consultancy Average                                        100000.0
# Number of faculty members                                        17
#
# Institution                                           IR-P-U-0853  \
# Total sanctioned approved intake for all programs           800.0
# Total number of students enrolled in all programs           883.0
# Total number of economically socially challenge...          352.0
# No. of students\rreceiving full\rtuition fee\rr...           58.0
# No. of students\rreceiving full\rtuition fee\rr...          154.0
# No. of students\rreceiving full\rtuition fee\rr...            1.0
# Median salary UG                                         440000.0
# Median salary PG                                    617333.333333
# Median Salary                                       528666.666667
# Total number of PhD students enrolled                       141.0
# Average Full Time PhD students graduated                     47.0
# Average Part Time PhD students graduated                      0.0
# Capex1                                                      493.5
# Capex2                                                      133.5
# Capex3                                                      238.1
# capexperstudavg                                          0.306447
# Opex1                                                       226.2
# Opex2                                                       196.1
# Opex3                                                       141.7
# opexperstudavg                                           0.199787
# Sponsored Average                                      14195449.0
# Consultancy Average                                 419183.333333
# Number of faculty members                                      71
#
# Institution                                           IR-P-U-0938
# Total sanctioned approved intake for all programs           410.0
# Total number of students enrolled in all programs           437.0
# Total number of economically socially challenge...          118.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# No. of students\rreceiving full\rtuition fee\rr...            8.0
# No. of students\rreceiving full\rtuition fee\rr...            0.0
# Median salary UG                                    236661.666667
# Median salary PG                                    326092.666667
# Median Salary                                       281377.166667
# Total number of PhD students enrolled                        20.0
# Average Full Time PhD students graduated                 6.666667
# Average Part Time PhD students graduated                      0.0
# Capex1                                                      140.0
# Capex2                                                       87.3
# Capex3                                                      119.7
# capexperstudavg                                          0.268992
# Opex1                                                        79.5
# Opex2                                                        65.1
# Opex3                                                        61.6
# opexperstudavg                                           0.159845
# Sponsored Average                                       1622757.0
# Consultancy Average                                 255165.666667
# Number of faculty members                                      31
#
# [23 rows x 80 columns]

# %%
nirf_df.to_excel(REPORT_FILE_DIRECTORY + "/PredictionReport.xlsx", freeze_panes=(1, 1),)
