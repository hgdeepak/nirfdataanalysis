# %%
import os
import numpy as np
import pandas as pd

# %%
PROCESSED_FILE_DIRECTORY = r"..\data\excel"

REPORT_FILE_DIRECTORY = r"..\data\report"

file = "1.IR-E-U-0456.xlsx"

sheet_name = "2"

# %%
files = os.listdir(PROCESSED_FILE_DIRECTORY)

files = [f for f in files if os.path.isfile(PROCESSED_FILE_DIRECTORY + '/' + f)]

# %%
column_name = 'Median salary of_x000D_placed graduates per_x000D_annum(Amount in_x000D_Rs.)'

for file in files:
    if "2" in pd.ExcelFile(PROCESSED_FILE_DIRECTORY + '\\' + file).sheet_names:
        excel_file = PROCESSED_FILE_DIRECTORY + '\\' + file
        data_df = pd.read_excel(excel_file, sheet_name="3")
        
        columns = data_df.columns.to_list()
        
        for index, element in enumerate(columns):
            print(index, element.split()[0])
# Out:
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 Academic
# 6 No.
# 7 No.
# 8 Median
# 9 No.
# 10 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 Academic
# 6 No.
# 7 No.
# 8 Median
# 9 No.
# 10 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 No.
# 6 Median
# 7 No.
# 8 Institution
# 0 Academic
# 1 No.
# 2 No.
# 3 Academic
# 4 No.
# 5 Academic
# 6 No.
# 7 No.
# 8 Median
# 9 No.
# 10 Institution
# ...

# %%
column_index
# Out:
# [8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8]
